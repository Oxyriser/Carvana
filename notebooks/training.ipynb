# %%
# Check the type of gpu assigned to the session:
# !nvidia-smi -L

# Trick to get more RAM:
# source https://towardsdatascience.com/upgrade-your-memory-on-google-colab-for-free-1b8b18e8791d
# a = []
# while(1):
#     a.append("1")

# %%
from google.colab import drive
drive.mount("/content/drive")

DRIVE_PATH = "/content/drive/MyDrive/"

#!cd drive/MyDrive && git clone https://github.com/Oxyriser/Carvana.git
# !cd drive/MyDrive/Carvana && git pull
# Out:
# Mounted at /content/drive
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 1), reused 25 (delta 1), pack-reused 0
# Unpacking objects: 100% (25/25), done.
# From https://github.com/Oxyriser/Carvana
#  + 1397d1e...763dcfc master     -> origin/master  (forced update)
# fatal: refusing to merge unrelated histories

# %%
# !cd drive/MyDrive/Carvana && pip install -r requirements.txt
# Out:
# Fetching origin
# HEAD is now at 617273c Initial commit
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# Traceback (most recent call last):
#   File "carvana/train.py", line 29, in <module>
#     from model import RCNN3D
#   File "/content/drive/My Drive/Carvana/carvana/model/__init__.py", line 3, in <module>
#     from .rpn import *
#   File "/content/drive/My Drive/Carvana/carvana/model/rpn.py", line 13, in <module>
#     from detectron2.modeling import (
# ImportError: cannot import name 'Box2BoxTransform'

# %%
# !cd drive/MyDrive/Carvana && python3 carvana/train.py --config-file configs/Flow-RCNN-3DRPN-v1.yaml
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# Command Line Args: Namespace(config_file='configs/Flow-RCNN-3DRPN-v1.yaml', dist_url='tcp://127.0.0.1:49152', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=[], resume=False)
# Loading an old v1 config file 'configs/Flow-RCNN-3DRPN-v1.yaml' by automatically upgrading to v2. See docs/CHANGELOG.md for instructions to update your files.
# [02/08 10:41:48 detectron2]: Rank of current process: 0. World size: 1
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# [02/08 10:41:48 detectron2]: Environment info:
# ---------------------  ---------------------------------------------------------------
# sys.platform           linux
# ...
